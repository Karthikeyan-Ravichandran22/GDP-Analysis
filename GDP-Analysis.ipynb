# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
import seaborn as sns

# %%
Gdp_current_Price=pd.read_csv(r"C:\Users\karth\Desktop\Decoder Lecture\Sessions\Case study 3 - GDP Analyis\Data 1\ab40c054-5031-4376-b52e-9813e776f65e (1).csv")

# %%
Gdp_current_Price.reset_index(inplace=True)

# %%
Gdp_current_Price.drop("index",axis=1)
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
#Initial we may face issue while create Pivot table in Pandas using our Data frame hence we droped some columns you can go through those steps above

table=pd.pivot_table(Gdp_current_Price,index=['index', 'Items  Description', 'Duration'])
table
# Out:
#                                                    All_India GDP  \
# index Items  Description                 Duration
# 0     GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
# 1     GSDP - CURRENT PRICES (` in Crore) 2012-13      9946636.00
# 2     GSDP - CURRENT PRICES (` in Crore) 2013-14     11236635.00
# 3     GSDP - CURRENT PRICES (` in Crore) 2014-15     12433749.00
# 4     GSDP - CURRENT PRICES (` in Crore) 2015-16     13675331.00
# 5     GSDP - CURRENT PRICES (` in Crore) 2016-17     15251028.00
# 6     (% Growth over previous year)      2012-13           13.86
# 7     (% Growth over previous year)      2013-14           12.97
# 8     (% Growth over previous year)      2014-15           10.65
# 9     (% Growth over previous year)      2015-16            9.99
# 10    (% Growth over previous year)      2016-17           11.52
#
#                                                    Andaman & Nicobar Islands  \
# index Items  Description                 Duration
# ...

# %%
print (Gdp_current_Price.columns.tolist())
# Out:
# ['index', 'Items  Description', 'Duration', 'Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands', 'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP']

# %%
Gdp_current_Price.drop('index',axis=1,inplace=True)

# %%
print(Gdp_current_Price.columns.tolist())
# Out:
# ['Items  Description', 'Duration', 'Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands', 'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP']

# %%
pivot_table=pd.pivot_table(Gdp_current_Price,index=['Items  Description', 'Duration'])
pivot_table
# Out:
#                                              All_India GDP  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13           13.86
#                                    2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
#                                    2016-17           11.52
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#                                    2016-17     15251028.00
#
#                                              Andaman & Nicobar Islands  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13                       11.13
# ...

# %%
Gdp_current_Price   # Need to Drop 5 and 10 row in our Data Because of Nan value
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
Gdp_current_Price=Gdp_current_Price.drop(index=[5,10] ,axis=0)
Gdp_current_Price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
states=Gdp_current_Price.columns.to_list()
states
# Out:
# ['Items  Description',
#  'Duration',
#  'Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
del states[0]

# %%
del states[0]

# %%
states
# Out:
# ['Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
Gdp_current_Price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
states_mean={}
for columns in Gdp_current_Price:
    if columns in states:
        mean=Gdp_current_Price[Gdp_current_Price["Items  Description"]=="(% Growth over previous year)"][columns].mean()
        states_mean[columns]=mean
states_mean["Items  Description"]="Average_Growth rate"
Gdp_current_Price=Gdp_current_Price.append(states_mean,ignore_index=True)

# %%
states_mean
# Out:
# {'Andhra Pradesh ': 12.6325,
#  'Arunachal Pradesh': 14.1625,
#  'Assam': 11.8775,
#  'Bihar': 13.765,
#  'Chhattisgarh': 13.3525,
#  'Goa': 2.02,
#  'Gujarat': 12.767500000000002,
#  'Haryana': 13.0425,
#  'Himachal Pradesh': 12.816666666666668,
#  'Jammu & Kashmir': 11.0025,
#  'Jharkhand': 12.567499999999999,
#  'Karnataka': 14.23,
#  'Kerala': 12.7525,
#  'Madhya Pradesh': 14.6475,
#  'Maharashtra': 12.103333333333333,
#  'Manipur': 11.89,
#  'Meghalaya': 7.6675,
#  'Mizoram': 16.866666666666664,
#  'Nagaland': 15.953333333333333,
#  'Odisha': 10.712499999999999,
#  'Punjab': 11.346666666666666,
#  'Rajasthan': 11.94,
#  'Sikkim': 10.4925,
#  'Tamil Nadu': 12.7125,
#  'Telangana': 12.497499999999999,
#  'Tripura': 15.613333333333335,
#  'Uttar Pradesh': 12.3675,
#  'Uttarakhand': 12.382499999999999,
#  'West Bengal1': nan,
#  'Andaman & Nicobar Islands': 12.9,
#  'Chandigarh': 12.754999999999999,
#  'Delhi': 12.572500000000002,
#  'Puducherry': 12.0975,
# ...

# %%
Gdp_current_Price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12      379402.0000
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13      411404.0000
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14      464272.0000
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15      526468.0000
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16      609934.0000
# 5       (% Growth over previous year)  2012-13           8.4300
# 6       (% Growth over previous year)  2013-14          12.8500
# 7       (% Growth over previous year)  2014-15          13.4000
# 8       (% Growth over previous year)  2015-16          15.8500
# 9                 Average_Growth rate      NaN          12.6325
#
#    Arunachal Pradesh        Assam       Bihar  Chhattisgarh       Goa  \
# 0         11063.0000  143175.0000  247144.000   158074.0000  42367.00
# 1         12547.0000  156864.0000  282368.000   177511.0000  38120.00
# ...

# %%
Gdp_current_Price_2015_16=Gdp_current_Price.iloc[[4,8,9]]

# %%
Gdp_2015_16=Gdp_current_Price_2015_16.T

# %%
Gdp_2015_16.columns=Gdp_2015_16.iloc[0]

# %%
Gdp_2015_16=Gdp_2015_16[1:]

# %%
Gdp_2015_16
# Out:
# Items  Description        GSDP - CURRENT PRICES (` in Crore)  \
# Duration                                             2015-16
# Andhra Pradesh                                        609934
# Arunachal Pradesh                                      18784
# Assam                                                 224234
# Bihar                                                 413503
# Chhattisgarh                                          260776
# Goa                                                    45002
# Gujarat                                               994316
# Haryana                                               485184
# Himachal Pradesh                                         NaN
# Jammu & Kashmir                                       118387
# Jharkhand                                             241955
# Karnataka                                        1.02707e+06
# Kerala                                                588337
# ...

# %%
Gdp_2015_16["Average_Growth rate"].sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **1.Rates of GDP Growth in North East States like mizoram,Tripura and Nagaland is High.**
#
# **2.States like Goa,Meghalaya,Odisha,Sikkim and J&K is Struggling with GDP Growth**
#
# **3.All India GDP is not so relatively Low**
#
# **4.GDP growth of Bihar,chattisgrarh, A&N ,AndhraPradesh,Karnataka and Arunachal Pradesh are relativelt high**
#
# **5.For all other States,GDP growth is medium**

# %%
Gdp_2015_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, Duration to All_India GDP
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GSDP - CURRENT PRICES (` in Crore)  25 non-null     object
#  1   (% Growth over previous year)       25 non-null     object
#  2   Average_Growth rate                 33 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
Gdp_2015_16["(% Growth over previous year)"]
# Out:
# Duration                     2015-16
# Andhra Pradesh                 15.85
# Arunachal Pradesh              12.07
# Assam                          13.19
# Bihar                          10.59
# Chhattisgarh                   10.98
# Goa                            10.75
# Gujarat                        11.09
# Haryana                        10.91
# Himachal Pradesh                 NaN
# Jammu & Kashmir                17.91
# Jharkhand                      11.44
# Karnataka                      11.42
# Kerala                         11.85
# Madhya Pradesh                 12.86
# Maharashtra                      NaN
# Manipur                          NaN
# Meghalaya                       9.58
# Mizoram                          NaN
# Nagaland                         NaN
# Odisha                          6.19
# Punjab                           NaN
# Rajasthan                        NaN
# Sikkim                          9.39
# Tamil Nadu                     10.99
# ...

# %%
datafr=pd.DataFrame(Gdp_2015_16["(% Growth over previous year)"])
datafr=datafr.iloc[1:,:]
datafr
# Out:
#                           (% Growth over previous year)
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# ...

# %%
plt.figure(figsize=(20,7))
datafr.sort_values(by="(% Growth over previous year)").drop("All_India GDP").plot.bar()
plt.show()

# %%
states
# Out:
# ['Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
states=['Andhra_Pradesh',
 'Arunachal_Pradesh',
 'Assam',
 'Bihar',
 'Chhattisgarh',
 'Goa',
 'Gujarat',
 'Haryana',
 'Himachal_Pradesh',
 'Jammu & Kashmir',
 'Jharkhand',
 'Karnataka',
 'Kerala',
 'Madhya_Pradesh',
 'Maharashtra',
 'Manipur',
 'Meghalaya',
 'Mizoram',
 'Nagaland',
 'Odisha',
 'Punjab',
 'Rajasthan',
 'Sikkim',
 'Tamil_Nadu',
 'Telangana',
 'Tripura',
 'Uttar_Pradesh',
 'Uttarakhand',
 'West Bengal1']

# %% [markdown]
# # Part-B

# %%
len(states)
# Out:
# 29

# %%
import os

# %%
gsva=pd.DataFrame()

# %%
path="C:\\Users\\karth\Desktop\\Decoder Lecture\\Sessions\\Case study 4 -GDP Analyis 2 +Python class\\GSVA\\"

# %%
list_of_files=os.listdir(path)
list_of_files
# Out:
# ['NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv',
#  'NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv',
#  'NAD-Assam-GSVA_cur_2015-16.csv',
#  'NAD-Bihar-GSVA_cur_2015-16.csv',
#  'NAD-Chandigarh-GSVA_cur_2015-16.csv',
#  'NAD-Chhattisgarh-GSVA_cur_2016-17.csv',
#  'NAD-Delhi-GSVA_cur_2016-17.csv',
#  'NAD-Goa-GSVA_cur_2015-16.csv',
#  'NAD-Gujarat-GSVA_cur_2015-16.csv',
#  'NAD-Haryana-GSVA_cur_2016-17.csv',
#  'NAD-Jammu_Kashmir-GSVA_cur_2015-16.csv',
#  'NAD-Jharkhand-GSVA_cur_2015-16.csv',
#  'NAD-Karnataka-GSVA_cur_2015-16.csv',
#  'NAD-Kerala-GSVA_cur_2015-16.csv',
#  'NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv',
#  'NAD-Maharashtra-GSVA_cur_2014-15.csv',
#  'NAD-Manipur-GSVA_cur_2014-15.csv',
#  'NAD-Meghalaya-GSVA_cur_2016-17.csv',
#  'NAD-Nagaland-GSVA_cur_2014-15.csv',
#  'NAD-Odisha-GSVA_cur_2016-17.csv',
#  'NAD-Puducherry-GSVA_cur_2016-17.csv',
#  'NAD-Punjab-GSVA_cur_2014-15.csv',
#  'NAD-Rajasthan-GSVA_cur_2014-15.csv',
#  'NAD-Sikkim-GSVA_cur_2015-16.csv',
# ...

# %%
for filename in list_of_files:
    for statename in states:
        if statename in filename:
            filepath=path+filename
            data=pd.read_csv(filepath,encoding="ISO-8859-1")
            data=data[["Item","2014-15"]]
            data=data.T
            data.columns=data.iloc[0]
            data=data[1:]
            data["state"]=statename
            gsva=pd.concat([data,gsva])

# %%
for filename in list_of_files:
    for statename in states:
        if statename in filename:
            filepath=path+filename
            data=pd.read_csv(filepath,encoding="ISO-8859-1")
            data=data[['Item','2014-15']]
            data=data.T
            data.columns=data.iloc[0]
            data=data[1:]
            data["state"]=statename
            gsva=pd.concat([data,gsva])  # Above we Instiated the Pd.DataFrame

# %%
gsva
# Out:
#         Agriculture, forestry and fishing        Crops    Livestock  \
# 2014-15                          25097754     16215212      7096876
# 2014-15                       1.60142e+06       866146       391188
# 2014-15                            799825       397591        88176
# 2014-15                           7591501      4162493      2951299
# 2014-15                          13064238      7297820      4693361
# 2014-15                            137447       114976        17338
# 2014-15                          15044394      7673441      5356257
# 2014-15                           9285716      5690972      2638842
# 2014-15                           6422978      4382636       788243
# 2014-15                            607897       375825       123800
# 2014-15                            366521       223330        72442
# 2014-15                            383140       226583        75483
# 2014-15                          16475655     10435121      3972829
# ...

# %%
gsva.set_index("state",inplace=True)

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
gsva.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
gsva["Per Capita GSDP (Rs.)"].sort_values().plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %%
gsva.columns.value_counts()
# Out:
# Secondary                                                               1
# Road transport                                                          1
# Electricity, gas, water supply & other utility services                 1
# Tertiary                                                                1
# Real estate, ownership of dwelling & professional services              1
# Gross State Domestic Product                                            1
# Trade, repair, hotels and restaurants                                   1
# Mining and quarrying                                                    1
# Per Capita GSDP (Rs.)                                                   1
# Livestock                                                               1
# Other services                                                          1
# Services incidental to transport                                        1
# Primary                                                                 1
# ...

# %%
len(gsva)
# Out:
# 50

# %%
gsva.index.value_counts()
# Out:
# Assam                2
# Andhra_Pradesh       2
# Bihar                2
# Jharkhand            2
# Manipur              2
# Punjab               2
# Nagaland             2
# Telangana            2
# Tamil_Nadu           2
# Meghalaya            2
# Haryana              2
# Uttarakhand          2
# Chhattisgarh         2
# Maharashtra          2
# Arunachal_Pradesh    2
# Kerala               2
# Goa                  2
# Rajasthan            2
# Odisha               2
# Gujarat              2
# Tripura              2
# Uttar_Pradesh        2
# Madhya_Pradesh       2
# Sikkim               2
# Karnataka            2
# Name: state, dtype: int64

# %%
gsva = gsva.drop_duplicates()

# %%
gsva.index.value_counts()
# Out:
# Assam                1
# Andhra_Pradesh       1
# Bihar                1
# Jharkhand            1
# Manipur              1
# Punjab               1
# Nagaland             1
# Telangana            1
# Tamil_Nadu           1
# Meghalaya            1
# Haryana              1
# Uttarakhand          1
# Chhattisgarh         1
# Maharashtra          1
# Arunachal_Pradesh    1
# Kerala               1
# Goa                  1
# Rajasthan            1
# Odisha               1
# Gujarat              1
# Tripura              1
# Uttar_Pradesh        1
# Madhya_Pradesh       1
# Sikkim               1
# Karnataka            1
# Name: state, dtype: int64

# %%
gsva["Per Capita GSDP (Rs.)"].sort_values().plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %%
gsva['Per Capita GSDP (Rs.)'].sort_values()["Goa"]/gsva['Per Capita GSDP (Rs.)'].sort_values()["Bihar"]
# Out:
# 8.004741709371503

# %%
list(gsva.columns).index("Secondary")
# Out:
# 10

# %%
gsva["Primary_gdp_precent"]=0
gsva["Secondary_gdp_percent"]=0
gsva["Tertiary_gdp_percent"]=0
# Out:
# <ipython-input-52-b1b2bc235c61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva["Primary_gdp_precent"]=0
# <ipython-input-52-b1b2bc235c61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva["Secondary_gdp_percent"]=0
# <ipython-input-52-b1b2bc235c61>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
gsva.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
for i in range(len(gsva)):
    gsva.iloc[i,37]=gsva.iloc[i,6]/gsva.iloc[i,30]
    gsva.iloc[i,38]=gsva.iloc[i,10]/gsva.iloc[i,30]
    gsva.iloc[i,39]=gsva.iloc[i,26]/gsva.iloc[i,30]
# Out:
# C:\Users\karth\anaconda3\envs\model\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
plt.figure(figsize=(20,10)) 
gsva[["Primary_gdp_precent","Secondary_gdp_percent","Tertiary_gdp_percent"]].plot(kind="bar",stacked=True)
plt.show()

# %%
plt.figure(figsize=(20,10)) 
gsva.sort_values("Per Capita GSDP (Rs.)")[["Primary_gdp_precent","Secondary_gdp_percent","Tertiary_gdp_percent"]].plot(kind="bar",stacked=True)
plt.show()

# %%
plt.figure(figsize=(10,7)) 
gsva.sort_values("Per Capita GSDP (Rs.)")["Population ('00)"].plot(kind="barh")
plt.show()

# %% [markdown]
# ### Inferences

# %% [markdown]
# ### 1. For states which has low per capita income, has significant dependence on primary source whereas states which have high per capta income relies more on secondary and tertiary
# ### 2. UP has high GDP but due to its population, has low per capita income
# ### 3.Nagaland is the only state more Percentage of Primaray and secondray compared to overall Per Capita GSDP

# %%
per_capita=gsva["Per Capita GSDP (Rs.)"].sort_values()

# %%
per_capita.quantile([.20,.50,.80,1])
# Out:
# 0.2    62809.4
# 0.5     104977
# 0.8     152898
# 1.0     271793
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
per_capita.sort_values(ascending=False)
# Out:
# state
# Goa                  271793
# Sikkim               240274
# Haryana              164077
# Kerala               154778
# Uttarakhand          153076
# Maharashtra          152853
# Tamil_Nadu           146503
# Karnataka            145141
# Gujarat              141263
# Telangana            139035
# Punjab               126606
# Arunachal_Pradesh    112718
# Andhra_Pradesh       104977
# Nagaland              89607
# Chhattisgarh          86860
# Rajasthan             84837
# Tripura               77358
# Meghalaya             76228
# Odisha                73979
# Madhya_Pradesh        62989
# Jharkhand             62091
# Assam                 60621
# Manipur               58442
# Uttar_Pradesh         49450
# Bihar                 33954
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
category_4=["Madhya_Pradesh","Jharkhand","Assam","Manipur","Uttar_Pradesh","Bihar"]

# %%
category_3=["Odisha","Meghalaya","Tripura","Rajasthan","Chhattisgarh","Nagaland","Madhya_Pradesh","Andhra_Pradesh"]

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
category_2=["Maharashtra","Tamil_Nadu","Karnataka","Gujarat","Telangana","Punjab","Arunachal_Pradesh","Uttarakhand"]

# %%
category_1=["Goa","Sikkim","Haryana","Kerala","Uttarakhand"]

# %%
categories_columns = ['Agriculture, forestry and fishing', 'Mining and quarrying', 'Manufacturing',
                      'Electricity, gas, water supply & other utility services', 'Construction',
                      'Trade, repair, hotels and restaurants',
                      'Transport, storage, communication & services related to broadcasting', 
                      'Financial services', 'Real estate, ownership of dwelling & professional services',
                      'Public administration', 'Other services', 'Taxes on Products', 'Subsidies on products']

# %% [markdown]
# # category_1

# %%
gsva.loc[category_1,categories_columns]
# Out:
#             Agriculture, forestry and fishing Mining and quarrying  \
# state
# Goa                                    308507                 3622
# Sikkim                                 137447                 1329
# Haryana                           8.01524e+06                25186
# Kerala                                5930617               558824
# Uttarakhand                       1.60142e+06               244549
#
#             Manufacturing  \
# state
# Goa               1177608
# Sikkim             550697
# Haryana       7.75692e+06
# Kerala            4273567
# Uttarakhand   5.86625e+06
#
#             Electricity, gas, water supply & other utility services  \
# state
# Goa                                                     204110
# Sikkim                                                  212499
# Haryana                                            1.10192e+06
# Kerala                                                  482470
# ...

# %%
agg=gsva.loc[category_1,categories_columns].sum()
agg
# Out:
# Agriculture, forestry and fishing                                       15993232.0
# Mining and quarrying                                                      833510.0
# Manufacturing                                                           19625045.0
# Electricity, gas, water supply & other utility services                  2434878.0
# Construction                                                            12607184.0
# Trade, repair, hotels and restaurants                                   15738265.0
# Transport, storage, communication & services related to broadcasting     7885253.0
# Financial services                                                       4321519.0
# Real estate, ownership of dwelling & professional services              15571552.0
# Public administration                                                    4150701.0
# Other services                                                           9042352.0
# ...

# %%
agg_gsdp=gsva.loc[category_1,'Gross State Domestic Product'].sum()
agg_gsdp
# Out:
# 118129206.0

# %%
(100*(agg/agg_gsdp)).sort_values(ascending=False)[0:6].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # category_2

# %%
agg=gsva.loc[category_2,categories_columns].sum()
agg_gsdp=gsva.loc[category_2,'Gross State Domestic Product'].sum()
(100*(agg/agg_gsdp)).sort_values(ascending=False)[0:6].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # category_3

# %%
agg=gsva.loc[category_3,categories_columns].sum()
agg_gsdp=gsva.loc[category_3,'Gross State Domestic Product'].sum()
(100*(agg/agg_gsdp)).sort_values(ascending=False)[0:6].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # category_4

# %%
agg=gsva.loc[category_4,categories_columns].sum()
agg_gsdp=gsva.loc[category_4,'Gross State Domestic Product'].sum()
(100*(agg/agg_gsdp)).sort_values(ascending=False)[0:6].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Part -C

# %%
drop_out=pd.read_csv(r"C:\Users\karth\Desktop\Decoder Lecture\Sessions\Case study 4 -GDP Analyis 2 +Python class\rs_session243_au570_1.1.csv")

# %%
drop_out
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
drop_out=drop_out.rename(columns={"Level of Education - State":"States"})
drop_out
# Out:
#       Sl. No.                States  Primary - 2012-2013  Primary - 2014-2015  \
# 0           1         A & N Islands                 0.68                 1.21
# 1           2        Andhra Pradesh                 3.18                 4.35
# 2           3     Arunachal Pradesh                15.16                10.89
# 3           4                 Assam                 6.24                 7.44
# 4           5                 Bihar                  NaN                 2.09
# 5           6            Chandigarh                  NaN                  NaN
# 6           7           Chhatisgarh                 4.14                 1.42
# 7           8  Dadra & Nagar Haveli                  NaN                 1.57
# 8           9           Daman & Diu                  NaN                 0.85
# 9          10                 Delhi                  NaN                  NaN
# 10         11                   Goa                  NaN                 0.20
# ...

# %%
drop_out.set_index("States",inplace=True)

# %%
drop_out=drop_out.replace({"Andhra Pradesh":"Andhra_Pradesh","Arunachal Pradesh":"Arunachal_Pradesh",
                      "Uttar Pradesh":"Uttar_Pradesh","Madhya Pradesh":"Madhya_Pradesh"},regex=True)

# %%
drop_out
# Out:
#                         Sl. No.  Primary - 2012-2013  Primary - 2014-2015  \
# States
# A & N Islands                 1                 0.68                 1.21
# Andhra Pradesh                2                 3.18                 4.35
# Arunachal Pradesh             3                15.16                10.89
# Assam                         4                 6.24                 7.44
# Bihar                         5                  NaN                 2.09
# Chandigarh                    6                  NaN                  NaN
# Chhatisgarh                   7                 4.14                 1.42
# Dadra & Nagar Haveli          8                  NaN                 1.57
# Daman & Diu                   9                  NaN                 0.85
# Delhi                        10                  NaN                  NaN
# Goa                          11                  NaN                 0.20
# Gujarat                      12                 0.74                 0.76
# ...

# %%
gsv_drop=pd.merge(gsva,drop_out,how="inner",left_index=True,right_index=True)

# %%
gsv_drop.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
gsv_primary=gsv_drop[["Per Capita GSDP (Rs.)","Primary - 2014-2015"]]
gsv_primary
# Out:
#             Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                     77358                 3.58
# Telangana                  139035                 5.81
# Sikkim                     240274                 4.57
# Rajasthan                   84837                 8.39
# Punjab                     126606                 1.29
# Odisha                      73979                 2.94
# Nagaland                    89607                19.41
# Meghalaya                   76228                10.34
# Manipur                     58442                18.00
# Maharashtra                152853                 0.55
# Kerala                     154778                  NaN
# Karnataka                  145141                 2.32
# Jharkhand                   62091                 6.41
# Haryana                    164077                 0.41
# Gujarat                    141263                 0.76
# Goa                        271793                 0.20
# ...

# %%
gsv_primary.dropna(inplace=True)
# Out:
# <ipython-input-84-7f3a88605ebe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsv_primary.dropna(inplace=True)

# %%
gsv_primary["Primary - 2014-2015"]=gsv_primary["Primary - 2014-2015"].astype(int) # astype will not work with nan value
# Out:
# <ipython-input-85-ecb57f645bd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsv_primary["Primary - 2014-2015"]=gsv_primary["Primary - 2014-2015"].astype(int) # astype will not work with nan value

# %%
gsv_primary
# Out:
#             Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                     77358                    3
# Telangana                  139035                    5
# Sikkim                     240274                    4
# Rajasthan                   84837                    8
# Punjab                     126606                    1
# Odisha                      73979                    2
# Nagaland                    89607                   19
# Meghalaya                   76228                   10
# Manipur                     58442                   18
# Maharashtra                152853                    0
# Karnataka                  145141                    2
# Jharkhand                   62091                    6
# Haryana                    164077                    0
# Gujarat                    141263                    0
# Goa                        271793                    0
# Bihar                       33954                    2
# ...

# %%
gsv_primary.plot.scatter(x=["Per Capita GSDP (Rs.)"],y=["Primary - 2014-2015"])
# Out:
# <AxesSubplot:xlabel='[Per Capita GSDP (Rs.)]', ylabel='[Primary - 2014-2015]'>

# %%
gsv_secondary=gsv_drop[["Per Capita GSDP (Rs.)","Secondary - 2014-2015"]]
gsv_secondary.dropna(inplace=True)
gsv_secondary["Secondary - 2014-2015"]=gsv_primary["Secondary - 2014-2015"].astype(int)
gsv_secondary.plot.scatter(x=["Per Capita GSDP (Rs.)"],y=["Secondary - 2014-2015"])
# Out:
# <ipython-input-88-19dc60401414>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsv_secondary.dropna(inplace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\model\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
